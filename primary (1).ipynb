# %% [markdown]
# ![Untitled design (1).png](attachment:ae37de1f-a041-49ac-9f3e-39e327b7dbcd.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kenya_primary_schools.csv')

# %%
df.head(10)
# Out:
#        X     Y    FID          Name_of_Sc          Level_  Status  \
# 0  36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1  36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2  36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3  36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4  37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
# 5  36.10  0.07  10006           POMBO PRI  PRIMARY SCHOOL  PUBLIC
# 6  36.13  0.10  10007     KIPNYUNGUNY PRI  PRIMARY SCHOOL  PUBLIC
# 7  36.14  0.13  10008        KABERGEI PRI  PRIMARY SCHOOL  PUBLIC
# 8  35.54  0.37  10009         KOPTEGA PRI  PRIMARY SCHOOL  PUBLIC
# 9  36.09  0.11  10010         CHOMIEK PRI  PRIMARY SCHOOL  PUBLIC
#
#                SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# 0  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# 1  RELIGIOUS ORGANIZATION  MIXED  DAY ONLY  ORDINARY  ...      0.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            X     Y    FID          Name_of_Sc          Level_  Status  \
# 0      36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1      36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2      36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3      36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4      37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
# ...      ...   ...    ...                 ...             ...     ...
# 31225  37.62 -1.47  30996        MGANGANI PRI  PRIMARY SCHOOL  PUBLIC
# 31226  37.96 -1.55  30997        KISIKINI PRI  PRIMARY SCHOOL  PUBLIC
# 31227  37.64 -1.45  30998     NGOMANO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 31228  37.98 -1.51  30999         NGILUNI PRI  PRIMARY SCHOOL  PUBLIC
# 31229  37.61 -1.49  31000      KIKASO PRI SCH  PRIMARY SCHOOL  PUBLIC
#
#                    SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            X     Y    FID          Name_of_Sc          Level_  Status  \
# 0      36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1      36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2      36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3      36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4      37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
# ...      ...   ...    ...                 ...             ...     ...
# 31225  37.62 -1.47  30996        MGANGANI PRI  PRIMARY SCHOOL  PUBLIC
# 31226  37.96 -1.55  30997        KISIKINI PRI  PRIMARY SCHOOL  PUBLIC
# 31227  37.64 -1.45  30998     NGOMANO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 31228  37.98 -1.51  30999         NGILUNI PRI  PRIMARY SCHOOL  PUBLIC
# 31229  37.61 -1.49  31000      KIKASO PRI SCH  PRIMARY SCHOOL  PUBLIC
#
#                    SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# ...

# %%
df.isnull().sum()
# Out:
# X              0
# Y              0
# FID            0
# Name_of_Sc     1
# Level_         1
# Status         1
# SchSponsor     1
# Type1          1
# Type2          1
# Type3          1
# PupilTeach     1
# ClassrmRat     1
# ToiletRati     1
# No_Classrm     1
# BoysToilet     1
# GirlsToilet    1
# TeachersTo     1
# TotalToile     1
# TotalBoys      1
# TotalGirls     1
# TotalEnrol     1
# GO_KTSC_M      1
# GOK_TSC_F      1
# authorityM     1
# authorityF     1
# PTA_BOG_M      1
# PTA_BOG_F      1
# OthersM        1
# OthersF        1
# NoTeaching     1
# NonTeachin     1
# Province       1
# District       1
# Division       1
# Location       1
# Costituenc     1
# Latitude       1
# Longitude      1
# dtype: int64

# %%
df_dropped_all_null = df.dropna(how='all')

# %%
df_dropped_all_null
# Out:
#            X     Y    FID          Name_of_Sc          Level_  Status  \
# 0      36.14  0.27  10001      CHEBIREBEI PRI  PRIMARY SCHOOL  PUBLIC
# 1      36.17  0.26  10002         WASEGES PRI  PRIMARY SCHOOL  PUBLIC
# 2      36.18  0.24  10003         KIRIBOT PRI  PRIMARY SCHOOL  PUBLIC
# 3      36.19  0.21  10004     KABUSWO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 4      37.70 -0.88  10005  VONDENI PRI SCHOOL  PRIMARY SCHOOL  PUBLIC
# ...      ...   ...    ...                 ...             ...     ...
# 31225  37.62 -1.47  30996        MGANGANI PRI  PRIMARY SCHOOL  PUBLIC
# 31226  37.96 -1.55  30997        KISIKINI PRI  PRIMARY SCHOOL  PUBLIC
# 31227  37.64 -1.45  30998     NGOMANO PRI SCH  PRIMARY SCHOOL  PUBLIC
# 31228  37.98 -1.51  30999         NGILUNI PRI  PRIMARY SCHOOL  PUBLIC
# 31229  37.61 -1.49  31000      KIKASO PRI SCH  PRIMARY SCHOOL  PUBLIC
#
#                    SchSponsor  Type1     Type2     Type3  ...  OthersF  \
# ...

# %%
df.describe()
# Out:
#                   X             Y          FID    PupilTeach    ClassrmRat  \
# count  31230.000000  31230.000000  31230.00000  31229.000000  31229.000000
# mean      36.525398     -0.608358  15615.50000     31.162045     30.516667
# std        1.549535      1.200350   9015.46879     24.833860     21.666361
# min       33.930000     -4.660000      1.00000      0.000000      0.000000
# 25%       35.010000     -1.230000   7808.25000     16.300000     17.300000
# 50%       36.810000     -0.560000  15615.50000     30.400000     29.600000
# 75%       37.660000      0.090000  23422.75000     42.100000     40.800000
# max       41.890000      5.290000  31230.00000    839.000000    839.000000
#
#          ToiletRati    No_Classrm    BoysToilet   GirlsToilet    TeachersTo  \
# count  31229.000000  31229.000000  31229.000000  31229.000000  31229.000000
# mean      34.776230      8.973710      4.563739      5.101444      1.907298
# ...

# %%
# Group by 'Province' and calculate the mean of selected numerical columns
grouped = df.groupby("Province")[["PupilTeach", "ClassrmRat", "ToiletRati"]].mean()

# Sort by Pupil-to-Teacher ratio for clarity
grouped = grouped.sort_values("PupilTeach", ascending=False)

# Display the grouped summary
grouped
# Out:
#                PupilTeach  ClassrmRat  ToiletRati
# Province
# NORTH EASTERN   41.107178   29.228960   41.561634
# WESTERN         38.458507   41.753922   39.869496
# COAST           38.094932   38.857926   58.652681
# RIFT VALLEY     32.668144   30.303024   33.901519
# NYANZA          31.713898   31.958660   45.296868
# EASTERN         29.855922   29.438136   30.568919
# CENTRAL         25.187884   22.863999   19.065631
# NAIROBI         18.025302   19.678807   27.739968
# Central          5.800000    7.300000   19.300000

# %%
# Check for provinces with extremely high or low values
grouped.style.highlight_max(color='lightcoral').highlight_min(color='lightgreen')
# Out:
# <style type="text/css">
# #T_b0950_row0_col0, #T_b0950_row1_col1, #T_b0950_row2_col2 {
#   background-color: lightcoral;
# }
# #T_b0950_row6_col2, #T_b0950_row8_col0, #T_b0950_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b0950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0950_level0_col0" class="col_heading level0 col0" >PupilTeach</th>
#       <th id="T_b0950_level0_col1" class="col_heading level0 col1" >ClassrmRat</th>
#       <th id="T_b0950_level0_col2" class="col_heading level0 col2" >ToiletRati</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Province</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0950_level0_row0" class="row_heading level0 row0" >NORTH EASTERN</th>
# ...

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["ToiletRati"], bins=30, kde=True, color="skyblue")
plt.title("Distribution of Pupil-to-Toilet Ratio")
plt.xlabel("Pupils per Toilet")
plt.ylabel("Number of Schools")
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
province_avg = df.groupby("Province")["PupilTeach"].mean().sort_values()

plt.figure(figsize=(12, 6))
sns.barplot(x=province_avg.values, y=province_avg.index, palette="viridis")
plt.title("Average Pupil-to-Teacher Ratio by Province")
plt.xlabel("Pupil-to-Teacher Ratio")
plt.ylabel("Province")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="PupilTeach", y="ClassrmRat", hue="Province", alpha=0.6)
plt.title("Pupil-to-Teacher vs Classroom Ratio")
plt.xlabel("Pupil-to-Teacher Ratio")
plt.ylabel("Pupil-to-Classroom Ratio")
plt.legend(title="Province", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
